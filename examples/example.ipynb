# %%
from plotProfile import ReactionProfilePlotter

energy_sets = {
    "Pathway A": [0.00, -2.0, 10.2, 1.4, -1.5, 2.0, -7.2],
    "Pathway B": [None, -2.0, 6.2, 4.3, 5.8, 2.0],
    "Pathway C": [None, -2.0, -6.8,-6.8],
}

annotations = {
    'Step 1': (0,3),
    'Step 2': (3,5),
    'Step 3': (5,6),
}

plotter = ReactionProfilePlotter(dashed=["Pathway C"])
plotter.plot(energy_sets, annotations=annotations, filename="../images/profile1")

plotter = ReactionProfilePlotter(style="presentation", dashed=["Pathway B"], point_type='bar', desaturate=False, colors='Blues_r', show_legend=False, curviness=0.5)
plotter.plot(energy_sets, filename="../images/profile2")

plotter = ReactionProfilePlotter(style="straight", figsize=(6,4), dashed=["Pathway C"], point_type='dot', annotation_color='black', axes='y', colors=['darkseagreen', 'slateblue', 'darksalmon'], energy='electronic', units='kj')
plotter.plot(energy_sets,annotations=annotations, filename="../images/profile3")

# %%
from plotProfile import ReactionProfilePlotter

energy_sets = {
    "1": [-3.0, 12.5, 2.9, 0.0, 1.8, 10.5, 2.9]
}

annotations = {
    'Path 1': (0,3),
    'Path 2': (3,6),
}

plotter = ReactionProfilePlotter(figsize=(4.5,4), axes='box', show_legend=False)
plotter.plot(energy_sets, annotations=annotations)

# %% [markdown]
# ### Exclude legend entries from the plot

# %%
from plotProfile import ReactionProfilePlotter

energies = { 
    "[2,3]-rearrangement": [0.0, -7.6, 10.1, -7.6, -8.8],
    "Sommelet-Hauser": [None, None, None, None, -8.8, -15.8],
    "diastereomer": [None, None, 11.8 ],
    "[1,2]-rearrangement": [ None, None, None, -7.6, -19.0, -19.0, -19.0 ]
}

annotations = {
    'deprotonation': (0,1),
    '[2,3]-rearrangement': (1,3),
    'release': (3,4),
    'branching': (4,5)
}

plotter = ReactionProfilePlotter(figsize=(8,4), dashed=["[1,2]-rearrangement", "Sommelet-Hauser"], colors=["midnightblue", "midnightblue", "midnightblue", "maroon"], axes="", annotation_size=10)
plotter.plot(energies, annotations=annotations, exclude_from_legend=["diastereomer"])
# Out:
# INFO: Not enough valid points for curve - just plotting an individual point for the energy series.
