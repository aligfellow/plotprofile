# %%
# import sys
# from pathlib import Path
# sys.path.append(str(Path("..") / "src"))

import plotProfile
import numpy as np

energy_sets = {
    "Pathway A": [0.00, -2.0, 10.2, 1.4, -1.5, 2.0, -7.2],
    "Pathway B": [np.nan, -2.0, 6.2, 4.3, 5.8, 2.0],
    "Pathway C": [np.nan, -2.0, -6.8,-6.8],
}

annotations = {
    'Step 1': (0,3),
    'Step 2': (3,5),
    'Step 3': (5,6),
}

plotter = plotProfile.plot.ReactionProfilePlotter(style="default", dashed=["off-cycle", "Pathway C"], point_type='hollow', desaturate=True, segment_annotations=annotations, axes="box")
plotter.plot(energy_sets)

plotter = plotProfile.plot.ReactionProfilePlotter(style="presentation", dashed=["off-cycle", "branching"], point_type='dot', desaturate=False, axes="box", colors='Blues_r', show_legend=False, curviness=0)
plotter.plot(energy_sets)

plotter = plotProfile.plot.ReactionProfilePlotter(figsize=(6,4), dashed=["off-cycle", "branching"], curviness=0.5, point_type='bar', desaturate=True, segment_annotations=annotations, annotation_color='black', axes='y', colors=['red', 'blue', 'green', 'orange', 'purple'], energy='electronic', units='kj')
plotter.plot(energy_sets)
# Out:
# /home/alig/bin/anaconda3/lib/python3.9/site-packages/scipy/__init__.py:155: UserWarning: A NumPy version >=1.18.5 and <1.26.0 is required for this version of SciPy (detected version 1.26.2
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
import sys
from pathlib import Path
sys.path.append(str(Path("..") / "src"))

import plotProfile
import numpy as np

energy_sets = {
    "1": [-3.0, 12.5, 2.9, 0.0, 1.8, 10.5, 2.9]
}

annotations = {
    'Path 1': (0,3),
    'Path 2': (3,6),
}

plotter = plotProfile.plot.ReactionProfilePlotter(figsize=(4.5,4), segment_annotations=annotations, axes='box', show_legend=False)
plotter.plot(energy_sets)
