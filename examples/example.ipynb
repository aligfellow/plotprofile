# %%
import os
import sys
from pathlib import Path
sys.path.append(str(Path("..") / "src"))

import plotProfile
import numpy as np

energy_sets = {
    "A": [0.00, 8.31, 0.00, 0.00, 0.00, 8.13, 18.5, 13.83, 0.00, -7.17],
    "B": [np.nan, 8.31, 1.0, 1.3, 11.73, 22.81, 19.02, 19.02, 19.02, 0.00],
    "C": [np.nan, 8.31, -10.4],
    "D": [np.nan, np.nan, np.nan, 0.0, -12.4],
}

annotations = [
    { 'start': 0, 'end': 6, 'label': 'H2 activation'},
    { 'start': 6, 'end': 9, 'label': 'hydride transfer'}, 
    ]

plotter = plotProfile.plot.ReactionProfilePlotter(style="default", dashed=["D"], point_type='hollow', segment_annotations=annotations, axes="box")
plotter.plot(energy_sets)

# plotProfile.plot.plot_profile(energy_sets, dashed=[2,3], curviness=0.5, desaturate=True)
