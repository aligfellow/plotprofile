# %%
from plotProfile import ReactionProfilePlotter

energy_sets = {
    "1": [-3.0, 12.54, 2.9, 0.0, 1.8, 10.5, 2.9],
    "2": [None, None, None, None, None, 13.5],
    "3": [None, None, 4.9, 4.9]
}

point_labels = {
    "1": ["0", "TS0", "2", "3" ,"4", "TS2", "5"],
    "2": [None, None, None, None, None, "TS1"],
    "3": [None, None, "6"]
}

annotations = {
    'Path 1': (0,3),
    'Path 2': (3,6),
}

plotter = ReactionProfilePlotter(figsize=(4.5,4), axes='box', show_legend=False)
plotter.plot(energy_sets, annotations=annotations, point_labels=point_labels,)

# %%
from plotProfile import ReactionProfilePlotter

energy_sets = {
    "Pathway A": [0.00, -2.0, 10.2, 1.4, -1.5, 2.0, -7.2],
    "Pathway B": [None, -2.0, 6.2, 4.3, 5.8, 2.0],
    "Pathway C": [None, -2.0, -6.8,-6.8, None, -2.0],
}

annotations = {
    'Step 1': (0,3),
    'Step 2': (3,5),
    'Step 3': (5,6),
}

point_labels = {
    "Pathway A": [None, None, "TS0a", None, "3", "TS2", None],
    "Pathway B": [None, None, "TS0b", None, "4", None],
    "diastereomer": [None, None, "TS0c"],
}

plotter = ReactionProfilePlotter(dashed=["Pathway C"])
plotter.plot(energy_sets, annotations=annotations, point_labels=point_labels)

# %%
from plotProfile import ReactionProfilePlotter

energies = { 
    "[2,3]-rearrangement": [0.0, -7.6, 10.1, -7.6, -8.8],
    "Sommelet-Hauser": [None, None, None, None, -8.8, -15.8],
    "": [None, None, 11.8 ],
    "[1,2]-rearrangement": [ None, None, None, -7.6, -19.0, -19.0, -19.0 ]
}

annotations = {
    'deprotonation': (0,1),
    '[2,3]-rearrangement': (1,3),
    'release': (3,4),
    'branching': (4,5)
}

plot_labels = {
    "[2,3]-rearrangement": [None, "53", "[2,3]-TS", "54", "[2-3]-product"],
    "Sommelet-Hauser": [None, None, None, None, None, "SH-product 4"],
    "[1,2]-rearrangement": [None, None, None, None, None, None, "[1,2]-product 6"],
}

plotter = ReactionProfilePlotter(figsize=(7,3) ,dashed=["[1,2]-rearrangement", "Sommelet-Hauser"], colors=["midnightblue", "midnightblue", "midnightblue", "maroon"], axes="", annotation_size=10)
plotter.plot(energies, annotations=annotations, point_labels=plot_labels)
